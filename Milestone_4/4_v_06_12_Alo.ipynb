# %% [markdown]
# # [NTDS'18] milestone 4: graph signal processing
# [ntds'18]: https://github.com/mdeff/ntds_2018
#
# [Rodrigo Pena](https://people.epfl.ch/254838), [EPFL LTS2](http://lts2.epfl.ch)

# %% [markdown]
# ## Students
#
# * Team: `<your team number>`
# * Students: `<the name of all students in the team>`
# * Dataset: `<the dataset you used to complete the milestone>`

# %% [markdown]
# ## Rules
#
# * Milestones have to be completed by teams. No collaboration between teams is allowed.
# * Textual answers shall be short. Typically one to two sentences.
# * Code has to be clean.
# * You cannot import any other library than we imported.
# * When submitting, the notebook is executed and the results are stored. I.e., if you open the notebook again it should show numerical results and plots. We won't be able to execute your notebooks.
# * The notebook is re-executed from a blank state before submission. That is to be sure it is reproducible. You can click "Kernel" then "Restart & Run All" in Jupyter.

# %% [markdown]
# ## Objective
#
# The goal of this milestone is to do some Graph Signal Processing (GSP) on the data of your project.
#
# ### A note about plotting
#
# There are several questions in this milestone that ask you to plot a signal on your network.
# There are several ways from which you could approach it.
# In all cases, compute the position of the nodes a single time at the beginning, as this is likely to be a costly operation.
# Using a single layout for all the graph plots will also make it easier to compare the plots.
# Indeed, the only thing changing between plots is the signal displayed.
# You can represent the features/labels lying on the graph via node **colors**.
# To do so, make sure to have a consistent color map throughout and remember to display a colorbar and scale in all plots, so that we can tell what numbers the colors represent.
#
# * An option is to use the **Laplacian eigenmaps** that you have seen in the previous milestone to embed your graph on the plane. For example:
#   ```
#   from matplotlib import pyplot as plt
#   plt.scatter(eigenvectors[:, 1], eigenvectors[:, 2], c=signal, alpha=0.5)
#   plt.colorbar()
#   ```
# * Another option is to use the plotting capabilities of **[NetworkX](https://networkx.github.io)**.
#   See the documentation of its [drawing methods](https://networkx.github.io/documentation/stable/reference/drawing.html).
#   For example:
#   ```
#   import networkx as nx
#   graph = nx.from_scipy_sparse_matrix(adjacency)
#   coords = nx.spring_layout(graph)  # Force-directed layout.
#   coords = eigenvectors[:, 1:3]  # Laplacian eigenmaps.
#   nx.draw_networkx_nodes(graph, coords, node_size=60, node_color=signal)
#   nx.draw_networkx_edges(graph, coords, alpha=0.3)
#   ```
# * Another option is to use the plotting capabilities of the **[PyGSP](https://github.com/epfl-lts2/pygsp)**, a Python package for Graph Signal Processing.
#   **Note that your are forbidden to use the PyGSP for anything else than plotting.**
#   See the documentation of its [plotting utilities](https://pygsp.readthedocs.io/en/stable/reference/plotting.html).
#   For example:
#   ```
#   import pygsp as pg
#   graph = pg.graphs.Graph(adjacency)
#   graph.set_coordinates('spring')  # Force-directed layout.
#   graph.set_coordinates(eigenvectors[:, 1:3])  # Laplacian eigenmaps.
#   graph.plot_signal(signal)
#   ```
# * Yet another option is to save your graph on disk, use **[Gephi](https://gephi.org)** externally, to visualize the graph, save the graph with the Gephi coordinates and finally load the nodes coordinates back into the notebook.
#
# We encourage you to try all the above methods before making your choice. Then be consistent and use only one throughout the milestone.
# NetworkX and PyGSP should already be installed in your environement. If that's not the case, install with `conda install networkx pygsp` (after activating the `ntds_2018` environment).

# %% [markdown]
# ## 0 - Load your network

# %%
# %matplotlib inline

# %% [markdown]
# If you get a `No module named 'pyunlocbox'` error when running the below cell, install the [pyunlocbox](https://github.com/epfl-lts2/pyunlocbox) with `conda install pyunlocbox` (after activating the `ntds_2018` environment).

# %%
import numpy as np
from scipy import sparse
import scipy.sparse.linalg
from matplotlib import pyplot as plt
from pyunlocbox import functions, solvers

import pandas as pd
import pygsp as pg
import networkx as nx

# %% [markdown]
# For this milestone, all we will need is a set of features/labels for each of the nodes on the network, as well as the Laplacian, $L,$ and Gradient, $\nabla_G,$ matrices that you have computed for your network while working on milestone 3.
#
# Import those objects in the cell below (or recompute the Laplacian and Gradient from your stored adjacency matrix, if you wish).
#
# _Note_: If your features/labels are not floating-point numbers, please convert them. For example, if your data has labels "cat" and "dog" for nodes that represent cats or dogs, respectively, you may assign the number `1.0` for the label "cat" and the number `-1.0` for the label "dog".

# %%
laplacian = np.load("../saved_laplacian_M3.npy")
adjacency = np.load("../saved_adjacency_red.npy")
n_nodes = len(adjacency)
n_links = int(np.where(adjacency > 0, 1, 0).sum()/2)

gradient = np.zeros((n_links,n_nodes))

eij = 0  # edge index
for i in range(n_nodes):
    for j in range(i, n_nodes, 1):
        wij = adjacency[i, j]
        if wij > 0:
            gradient[eij,i] = np.sqrt(wij)
            gradient[eij,j] = -np.sqrt(wij)
            eij += 1  # increment the edge index
            
# We still need to normalize our gradient by the degrees
degrees = np.sum(adjacency, 0 )
d_inv_sqrt = np.diag(np.sqrt(1/degrees))

gradient = sparse.csr_matrix(gradient) @ sparse.csr_matrix(d_inv_sqrt)

# Controlling that the relation between gradient and laplacian is verified
np.testing.assert_allclose((gradient.T @ gradient).toarray(), laplacian)

# %%
# Uploading our dataframe to extract the labels
features = pd.read_csv('../saved_features_M3.csv')
drop=(['Unnamed: 0','Unnamed: 0.1','title','cast','crew','genres','keywords','original_language']
          +['production_companies','production_countries','release_date','runtime','vote_count','keywords_key']
          +['keywords_names','genres_name','index_by_cluster','cluster'])
features = features.drop(columns=drop)
features['profitability']=features['net_profit']=""
features.profitability = features.revenue/features.budget
features.net_profit = features.revenue-features.budget
features = features.drop(columns=['movie_id','budget','revenue'])
features.vote_average=features.vote_average*10

labels = features.values.astype(int)

# %% [markdown]
# ## 1 - Graph Fourier Transform
#
# In this section we will observe how your feature/label vector looks like in the "Graph Fourier" domain.

# %% [markdown]
# ### Question 1
#
# Compute the Fourier basis vectors and the Laplacian eigenvalues. Make sure to order those from smaller to larger, $\lambda_0 \leq \lambda_1 \leq \dots \leq \lambda_{N-1},$ and use the same ordering for the Fourier basis vectors.

# %%
eigenvalues, eigenvectors = np.linalg.eigh(laplacian)

e = eigenvalues
U = eigenvectors.T

# %% [markdown]
# Plot the first 3 and the last Fourier basis vectors as signals on your graph. Clearly indicate which plot belongs to which basis vector.

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,3,1)
plt.title("aligned w/ the x-axis as we used it to eigenmap")
signal = U[1]
plt.scatter(U[1], U[2], c=signal, alpha=0.5)
plt.colorbar()
plt.subplot(2,3,2)
plt.title("aligned w/ the y-axis as we used it to eigenmap")
signal = U[2]
plt.scatter(U[1], U[2], c=signal, alpha=0.5)
plt.colorbar()
plt.subplot(2,3,3)
signal = U[3]
plt.scatter(U[1], U[2], c=signal, alpha=0.5)
plt.colorbar()

# Les valeurs qui changent beaucoup sont "cachées" sous les autres noeuds, en changeant le système de coordonnées
# (càd le choix de vecteurs propre sur lequel on fait le eigenmap) on peut voir apparaître des variations très haute fréquence mais très localisées
plt.subplot(2,3,4)
signal = U[1000]
plt.scatter(U[1], U[1000], c=signal, alpha=0.5)
plt.colorbar()

# %% [markdown]
# ### Question 2
#
# What can you observe in terms of local variations when comparing the basis vectors corresponding to the smallest eigenvalues to those corresponding to the largest eigenvalue? How would this justify the interpretation of the eigenvalues as "graph frequencies"?

# %% [markdown]
# **Your answer here.**
#
# We can see on the above plots that when we use the eigenvectors as signal over the graph, we are thus plotting their values at each node as a color variation. The fist eigenvectors present small variations from node to node, they are smooth. This is explained by the fact that as they correspond to the first eigenvalues, they are "low frequency" signals.

# %% [markdown]
# ### Question 3
#
# Implement a function that returns the Graph Fourier Transform (GFT) of a given vector $x \in \mathbb{R}^{N},$ with respect to your graph, and a function that computes the corresponding inverse GFT (iGFT).

# %%
def GFT(x):
    return U @ x 

def iGFT(x):
    return U.T @ x

# %% [markdown]
# ### Question 4
#
# Plot your feature/label vector as a signal on your graph

# %%
graph = pg.graphs.Graph(adjacency)
graph.set_coordinates('random3D')  # Force-directed layout.
graph.set_coordinates(eigenvectors[:, 1:3])  # Laplacian eigenmaps en changeant les coordonnées ont voit des trucs

signal = labels[:,1]
graph.plot_signal(signal)

# %% [markdown]
# Plot the absolute values of the GFT of your feature/label signal as a function of the graph eigenvalues. Make sure to add a marker indicating the position of each graph eigenvalue, and remember to properly name the axes.

# %%
s = labels[:,1]

plt.figure(figsize=[5,5])
plt.title("GFT of our labels")
ft_lab_0 = GFT(s)
# Note that the x axis is given by the eigenvalues (frequencies) to which corresponds each eigenvector
plt.bar(eigenvalues,np.abs(ft_lab_0), width=0.01)

print("square norm of the gradient of the signal :", s.T@laplacian@s )
print("Max diff between signal and reconstructed signal (iGFT(GFT()) :",np.max(labels[:,0]-iGFT(GFT(labels[:,0]))))
# Out:
# square norm of the gradient of the signal : 741514.106493599
# Max diff between signal and reconstructed signal (iGFT(GFT()) : 5.080380560684716e-13

# %% [markdown]
# ### Question 5
#
# Discuss the behavior of the GFT that you plotted in the last question via comparing the plot of your label signal and those of the Fourier basis of Question 1. Would you consider your labels a "low-pass" or "high-pass" signal, or yet something else entirely?

# %% [markdown]
# **Your answer here.**

# %% [markdown]
# ## 2 - Filtering on graphs
#
# In this section we will check how filtered Dirac impulses diffuse on your graph.

# %% [markdown]
# ### Question 6
#
# Implement the following three filter kernels and the graph filtering operation.
#
# - The **heat kernel** is supposed to take in a vector of eigenvalues `e` and a parameter `t` and output a vector of evaluations of the heat kernel at those eigenvalues (see the course slides for help).
# - The **inverse filter** kernel is supposed to take in a vector of eigenvalues `e` and a parameter `t` and implement spectrally the  filter defined in the node domain by $f_{out}  = (I + t L)^{-1} f_{in},$ where $f_{in}, f_{out} \in \mathbb{R}^{N}$ are, repectively, the input and output signals to the filter.
# - The **rectangle kernel** takes in a vector of eigenvalues `e` and parameters `l_min` and `l_max` and returns `1.0` at coordinates satisfying $(e[l] \geq l_{min}) \wedge (e[l] \leq l_{max}),$ and `0.0` otherwise.
# - The **graph filtering** operation takes a graph signal $x \in \mathbb{R}^{N}$, a spectral graph `kernel` and a set of keyworded variables, and returns the corresponding filtered signal.
#     - _Hint:_ Remember that you have implemented the `GFT` and `iGFT` operations in Question 3.
#     - The `**kwargs` is a placeholder to collect supplementary pairs of keyword-values that are not known by the implementation before execution time.
#       The `kwargs` variable is a dictionary whose keyes and values are the parameter names and values.
#       This is useful to allow both `graph_filter(x, heat_kernel, tau=1.0)` and `graph_filter(x, rectangle_kernel, lambda_min=0.0, lambda_max=1.0)` to be valid calls from the same implementation.
#       One can then defer the keyword-value assignment to the `kernel` call: `foo = kernel(bar, **kwargs)`.

# %%
def heat_kernel(e, t):
    return np.exp(-t*e)
    
def heat_kernel_norm(e, t):
    return np.exp(-t*np.divide(e,max(e)))

def inverse_kernel(e, t):
    return np.divide(1,((np.ones(n_nodes)+t*np.divide(e,max(e)))))

def rectangle_kernel(e, l_min, l_max):
    return np.concatenate((np.zeros(l_min),np.ones(l_max-l_min),np.zeros(n_nodes-l_max)))

def graph_filter(x, kernel, **kwargs):
    return iGFT(kernel(e, **kwargs)*GFT(x))

# %% [markdown]
# ### Question 7
#
# Plot all three filter kernels in the spectral domain. Remember to properly name the axes and title the plots. Choose filter parameters that best approximate the behavior of the GFT of your feature/label signal (as seen in Question 4).

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,3,1)
plt.plot(e,heat_kernel(e,t=2))

plt.subplot(1,3,2)
plt.plot(e,inverse_kernel(e,t=3))

plt.subplot(1,3,3)
plt.plot(e,rectangle_kernel(e,l_min=0, l_max=600))

# %% [markdown]
# ### Question 8
#
# Consider two Dirac impulses arbitrarily placed on your graph. Plot their filtered versions by the three filter kernels implemented in Question 6.

# %%
s = np.zeros(n_nodes)
s[1] = s[837] = 1.

plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
plt.scatter(U[1], U[2], c=s, alpha=0.33, cmap='YlOrRd')
plt.colorbar()

plt.subplot(122)
plt.scatter(U[1], U[2], c = graph_filter(s, heat_kernel, t=5), alpha = 0.33, cmap='YlOrRd')
plt.colorbar()

# %% [markdown]
# Comment on the "diffusion" of the Diracs induced by the filters. What does it say about the "communication" of information across your network? Relate that to the network connectivity measures that you analyzed during the previous milestones.

# %% [markdown]
# **Your answer here.**

# %% [markdown]
# ## 3 - De-noising
#
# In this section we will add some centered Gaussian noise to your feature/label signal and attempt to recover it.

# %% [markdown]
# ### Question 9
#
# In the cell below, set the noise variance $\sigma^2$ by making sure that the signal-to-noise ratio $SNR = \frac{\operatorname{Var}(\text{labels})}{\sigma^2}$ is about  $1.5$.
#
# _Note:_ Actually, you might want to play with the noise variance here and set it to different values and see how the denoising filters behave.

# %%
SNR=1.5
noise_variance = np.var(labels[:,1])/SNR
noisy_measurements = labels[:,1] + noise_variance * np.random.randn(n_nodes)

# %% [markdown]
# ### Question 10
#
# In the denoising setting, a common graph signal processing assumption is that the signal $z$ that we want to recover is "smooth", in the sense that $\|\nabla_G z\|_2 = \sqrt{z^{\top} L z}$ is small, while remaining "close" to the measurements that we start with. This leads to denoising by solving the following optimization problem:
#
# $$
# z^\star = \text{arg} \, \underset{z \in \mathbb{R}^{N}}{\min} \, \|z - y\|_2^2 + \gamma z^{\top} L z,
# $$
#
# where $y \in \mathbb{R}^{N}$ is the vector of noisy measurements.
#
# Derive the close form solution to this problem giving $z^\star$ as a function of $y$, $\gamma$ and $L$. Does this solution correspond to any graph filtering operation that you know?

# %% [markdown]
# **Your answer here.**
#
#
# A VERIFIER <br>
# the closed form solution is given by:
# $z^\star  = (I + \gamma L)^{-1} z$ <br>
# Finding the solution to this problem is equivalent to applying the inverse kernel on the signal.

# %% [markdown]
# ### Question 11
#
# Now, denoise the noisy measurements by passing them through the filters that you implemented in Question 6. Choose the filter parameters based on the behavior of the GFT of your original label signal (this is the prior knowledge that you input to the problem).

# %%
z_heat_denoised = graph_filter(noisy_measurements, heat_kernel, t=2)
z_inv_denoised = graph_filter(noisy_measurements, inverse_kernel, t=3)
z_rect_denoised = graph_filter(noisy_measurements, rectangle_kernel, l_min=0, l_max=300)

# %% [markdown]
# Plot, on your graph, the original label signal, the noisy measurements, and the three denoised version obtained above. Report on each plot the value of the corresponding relative error
# $$
# \text{rel-err} = \frac{\|\text{labels} - z \|_2}{\|\text{labels}\|_2},
# $$
# where $z$ is the plotted signal.

# %%
#plt.figure(figsize=(10,5))
#plt.plot(labels[:,1])
#plt.plot(noisy_measurements, "r")
#plt.plot(z_heat_denoised)
#plt.plot(z_inv_denoised, "y")
#plt.plot(z_rect_denoised, "b")

rel_err_noisy=np.mean(np.abs(labels[:,1]-noisy_measurements)/labels[:,1])
print(rel_err_noisy)
rel_err_heat=np.mean(np.abs(labels[:,1]-z_heat_denoised)/labels[:,1])
print(rel_err_heat)
rel_err_inv=np.mean(np.abs(labels[:,1]-z_inv_denoised)/labels[:,1])
print(rel_err_inv)
rel_err_rect=np.mean(np.abs(labels[:,1]-z_rect_denoised)/labels[:,1])
print(rel_err_rect)


graph.plot_signal(labels[:,1])
plt.title("label")
graph.plot_signal(noisy_measurements)
plt.title("noisy")
graph.plot_signal(z_heat_denoised)
plt.title("heat_denoised")
graph.plot_signal(z_inv_denoised)
plt.title("inverse_denoised")
graph.plot_signal(z_rect_denoised)
plt.title("rectangle_denoised")
# Out:
# 0.5860368558899567
# 0.25025931168200094
# 0.25676830670296863
# 0.31130665753015135
# Text(0.5, 1.0, 'rectangle_denoised')

# %% [markdown]
# Finally, overlay on the same plot the GFT of all five signals above.

# %%
# Your code here.
plt.figure(figsize=(30,7))

plt.subplot(1,5,1)
plt.plot(np.abs(GFT(labels[:,1])),'b',linewidth=0.5)

plt.subplot(1,5,2)
plt.plot(np.abs(GFT(noisy_measurements)), 'r', linewidth=0.5)

plt.subplot(1,5,3)
plt.plot(np.abs(GFT(z_heat_denoised)))

plt.subplot(1,5,4)
plt.plot(np.abs(GFT(z_inv_denoised)), 'y', linewidth=0.5)

plt.subplot(1,5,5)
plt.plot(np.abs(GFT(z_rect_denoised)), 'c', linewidth=0.5)

# %% [markdown]
# ### Question 12
#
# Comment on which denoised version seems to best match the original label signal. What is the underlying assumption behind the three filtering approaches? Do you think it holds for your label signal? Why?

# %% [markdown]
# **Your answer here.**

# %% [markdown]
# ## 4 - Transductive learning
#
# It is often the case in large networks that we can only afford to query properties/labels on a small subset of nodes. Nonetheless, if the underlying labels signal is "regular" enough, we might still be able to recover a good approximation of it by solving an offline variational problem, with constraints on the values of the measured nodes.
#
# In this section, we will be interested in solving such transductive learning problems by minimizing a (semi-) p-norm of the graph gradient applied to the signal of interest:
#
# $$
# \text{arg} \, \underset{z|_S = y}{\min} \|\nabla_G z\|_p^p,
# $$
#
# where $S$ is the set of measured nodes.
#
# In English, we can say that we are looking for solutions with small "aggregated local variations", as measured by $\|\nabla_G z\|_p^p = \sum_{i=1}^{n} \sum_{j=1}^{n} \left( \sqrt{W_{ij}} |z[i] - z[j]| \right)^p,$ while satisfying the measurement constraints $z[i] = y[i]$ for $i \in S.$
#
# We will work with two cases, according to the choices $p=1$ or $p=2.$ For $p=1,$ the problem is known as "interpolation by graph total-variation minimization," whereas for $p=2$ it is sometimes called "interpolation by Tikhonov regularization".
#
# In order to solve these variational problems with the black-box solver provided to you, you will use the [pyunlocbox](https://pyunlocbox.readthedocs.io). This toolbox implements iterative solvers based on so-called ["proximal-splitting"](https://en.wikipedia.org/wiki/Proximal_gradient_method) methods.

# %% [markdown]
# ### Question 13
#
# Throughout this section, we will consider only a binarized version of your label signal. If your variable `labels` currently has values other than $\{-1, 1\},$ threshold them so that those are the only values taken in this vector. This can be done for example by choosing a number $t \in \mathbb{R}$ and then setting $\text{labels_bin}[i] = 1$ if $\text{labels}[i] \geq t$ and $\text{labels_bin}[i] = 0$ otherwise.

# %%
labels_bin = np.where(labels[:,1] < 70, -1, 1)
labels_bin[:20]


# Testing with an eigenvector as it is smooth over the graph 

labels_bin = np.where(U[1] < np.median(U[1]), -1, 1)

plt.figure(figsize=(10,3))
plt.subplot(121)
plt.scatter(U[1], U[2], c=U[1], alpha=0.8)
plt.colorbar()

plt.subplot(122)
plt.scatter(U[1], U[2], c=labels_bin, alpha=0.8)
plt.colorbar()

# %% [markdown]
# Now, subsample this binarized label signal by $70\%$ by choosing, uniformly at random, $30\%$ of the nodes whose labels we will keep.
#
# You will do this by computing a "measurement mask" vector `w` with `1.0`'s at the measured coordinates, and $0.0$'s otherwise.

# %%
mn_ratio = 0.1
m = int(mn_ratio * n_nodes)  # Number of measurements.

w = np.random.permutation(np.concatenate((np.ones(m),np.full(n_nodes-m, np.nan))))

# %% [markdown]
# Plot the subsampled signal on the graph. _Hint:_ you might want to set to `numpy.nan` the values of the un-measured nodes for a cleaner plot.

# %%
training = labels_bin * w

plt.scatter(U[1], U[2], c=training, alpha=0.8)
plt.colorbar()

# %% [markdown]
# ### Interlude
#
# For the solution of the variational problems you can use the following function as a "black-box".
#
# You will just need to provide a `gradient` matrix (which you should already have from Section 0), and an orthogonal projection operator `P` onto the span of the measured coordinates (made precise in the next question).

# %%
def graph_pnorm_interpolation(gradient, P, x0=None, p=1., **kwargs):
    r"""
    Solve an interpolation problem via gradient p-norm minimization.

    A signal :math:`x` is estimated from its measurements :math:`y = A(x)` by solving
    :math:`\text{arg}\underset{z \in \mathbb{R}^n}{\min}
    \| \nabla_G z \|_p^p \text{ subject to } Az = y` 
    via a primal-dual, forward-backward-forward algorithm.

    Parameters
    ----------
    gradient : array_like
        A matrix representing the graph gradient operator
    P : callable
        Orthogonal projection operator mapping points in :math:`z \in \mathbb{R}^n` 
        onto the set satisfying :math:`A P(z) = A z`.
    x0 : array_like, optional
        Initial point of the iteration. Must be of dimension n.
        (Default is `numpy.random.randn(n)`)
    p : {1., 2.}
    kwargs :
        Additional solver parameters, such as maximum number of iterations
        (maxit), relative tolerance on the objective (rtol), and verbosity
        level (verbosity). See :func:`pyunlocbox.solvers.solve` for the full
        list of options.

    Returns
    -------
    x : array_like
        The solution to the optimization problem.

    """
    
    grad = lambda z: gradient.dot(z)
    div = lambda z: gradient.transpose().dot(z)

    # Indicator function of the set satisfying :math:`y = A(z)`
    f = functions.func()
    f._eval = lambda z: 0
    f._prox = lambda z, gamma: P(z)

    # :math:`\ell_1` norm of the dual variable :math:`d = \nabla_G z`
    g = functions.func()
    g._eval = lambda z: np.sum(np.abs(grad(z)))
    g._prox = lambda d, gamma: functions._soft_threshold(d, gamma)

    # :math:`\ell_2` norm of the gradient (for the smooth case)
    h = functions.norm_l2(A=grad, At=div)

    stepsize = (0.9 / (1. + scipy.sparse.linalg.norm(gradient, ord='fro'))) ** p

    solver = solvers.mlfbf(L=grad, Lt=div, step=stepsize)

    if p == 1.:
        problem = solvers.solve([f, g, functions.dummy()], x0=x0, solver=solver, **kwargs)
        return problem['sol']
    if p == 2.:
        problem = solvers.solve([f, functions.dummy(), h], x0=x0, solver=solver, **kwargs)
        return problem['sol']
    else:
        return x0

# %% [markdown]
# ### Question 14
#
# During the iterations of the algorithm used for solving the variational problem, we have to make sure that the labels at the measured nodes stay the same. We will do this by means of an operator `P` which, given a vector $a \in \mathbb{R}^{N},$ returns another vector $b \in \mathbb{R}^{N}$ satisfying $b[i] = \text{labels_bin}[i]$ for every node $i$ in the set $S$ of known labels, and $b[i] = a[i]$ otherwise. Write in the cell below the function for this orthogonal projection operator `P`.
#
# _Hint:_ remember you have already computed the mask `w`.

# %%
def P(a):
    b1=labels_bin * np.nan_to_num(w)
    b2=(1-np.nan_to_num(w)) * a
    b=b1+b2
    return b

# %% [markdown]
# ### Question 15
#
# Solve the variational problems for $p = 1$ and $p = 2$. Record the solution for the $1-$norm minimization under `sol_1norm_min` and the one for $2-$norm minimization under `sol_2norm_min`.
#
# Compute also binarized versions of these solutions by thresholding the values with respect to $0$, that is, non-negative values become `1.0`, while negative values become `-1.0`. Store those binarized versions under `sol_1norm_bin` and `sol_2norm_bin`, respectively.

# %%
sol_1norm_min = graph_pnorm_interpolation(gradient, P, x0=np.random.randn(n_nodes), p=1., rtol = 1e-5, maxit = 5000000)

sol_2norm_min = graph_pnorm_interpolation(gradient, P, x0=np.random.randn(n_nodes), p=2., rtol = 1e-5, maxit = 5000000)

# %%
threshold = 0

sol_1norm_bin = np.where(sol_1norm_min < threshold, -1, 1)

sol_2norm_bin = np.where(sol_2norm_min < threshold, -1, 1)

# %% [markdown]
# Plot, on your graph, the original `labels_bin` signal, as well as the solutions to the variational problems (both binarized and otherwise). Indicate on each plot the value of the relative error $\text{rel-err} = \frac{\|\text{labels_bin} - z\|_2}{\|\text{labels_bin}\|_2}$, where $z$ is the signal in the corresponding plot.

# %%
plt.figure(figsize=(14,6))
plt.subplot(231)
plt.scatter(U[1], U[2], c=labels_bin, alpha=0.8)
plt.colorbar()

plt.subplot(232)
rel_err = (np.linalg.norm(labels_bin - sol_1norm_bin)/(np.linalg.norm(labels_bin)))
plt.title(" relative error : " + np.array2string(rel_err))
plt.scatter(U[1], U[2], c = sol_1norm_bin, alpha=0.8)
plt.colorbar()

plt.subplot(233)
rel_err = (np.linalg.norm(labels_bin - sol_2norm_bin)/(np.linalg.norm(labels_bin)))
plt.title(" relative error : " + np.array2string(rel_err))
plt.scatter(U[1], U[2], c = sol_2norm_bin, alpha=0.8)
plt.colorbar()

# %% [markdown]
# ### Question 16
#
# Now that you have got a feeling for the sort of solutions that the transductive learning problems studied can give, we will see what is the effect of the number of measurements on the accuracy of both $p-$norm minimization problems.
#
# Towards this goal, you will write a `phase_transition()` function. This function will basically go over all the procedures that you have implemented in this section, but for varying numbers of measurements and thresholding values. It will also compute the relative error, $\text{rel-err},$ of the solutions and average them over a number of trials.
#
# The output of the `phase_transition()` function has to be a matrix with `len(mn_ratios)` columns and `len(thresholds)` rows. Each pixel $(i,j)$ in the output matrix has to contain the average, over `n_trials` trials, of the relative error $\text{rel-err}$ in the binarized (with threshold `thresholds[i]`) solution given by `graph_pnorm_interpolation()` from observing an `mn_ratios[j]` fraction of nodes. The randomness comes from a different choice of mask `w` at each trial, hence the averaging.
#
# The interest of this phase transition matrix is to assess what level of recovery error one could expect for a certain fraction of measurements and a certain threshold level.

# %%
def phase_transition(mn_ratios, thresholds, n_trials, labels_bin, p):

    n_nodes = len(labels_bin)
    
    meas = (mn_ratios * n_nodes).astype(int)  # Number of measurements.
    sol = np.zeros((n_trials, n_nodes))
    sol_bin = np.zeros((n_trials, n_nodes))
    pt_matrix = np.zeros((len(thresholds), len(mn_ratios)))
    
    # Solve p-norm interpolation.
    for m in range(len(meas)):
        
        print(m,'m done over',len(meas))
        
        for i in range(n_trials) :
            w = np.random.permutation(np.concatenate((np.ones(meas[m]),np.full(n_nodes-meas[m], np.nan))))
            P_fun = lambda a: labels_bin * np.nan_to_num(w)+(1-np.nan_to_num(w)) * a
            sol[i] = graph_pnorm_interpolation(gradient, P_fun, x0=np.random.randn(n_nodes), p=p, rtol = 1e-5, maxit = 5000)

        # Aggregate.
        for j in range(len(thresholds)) :
            rel_err=0
            
            for i in range(n_trials):
                sol_bin[i] = np.where(sol[i] < thresholds[j], -1, 1)
                rel_err += (np.linalg.norm(labels_bin - sol_bin[i])/(np.linalg.norm(labels_bin)))
                
            pt_matrix[j, m] = rel_err/n_trials
            
    return pt_matrix

# %% [markdown]
# ### Question 17
#
# Pick 5 "m/n" ratios in $(0, 1)$ and 5 threshold levels in $(-1, 1)$ and run the `phase_transition()` function with `n_trials` = 20, for both $p = 1$ and $p = 2$.

# %%
## The magic prevents the 10000 prints of the function

mn_ratios = np.array([0.1, 0.3, 0.5, 0.7, 0.9])

thresholds = np.array([-1, -0.5, 0, 0.5, 1])

n_trials= 20

pt_matrix_1norm = phase_transition(mn_ratios, thresholds, n_trials, labels_bin, 1);

print('part 1 done')

pt_matrix_2norm = phase_transition(mn_ratios, thresholds, n_trials, labels_bin, 2);
# Out:
# 0 m done over 5
# Solution found after 2025 iterations:
#     objective function f(sol) = 5.882204e+03
#     stopping criterion: RTOL
# Solution found after 670 iterations:
#     objective function f(sol) = 1.144494e+04
#     stopping criterion: RTOL
# Solution found after 1382 iterations:
#     objective function f(sol) = 9.104877e+03
#     stopping criterion: RTOL
# Solution found after 954 iterations:
#     objective function f(sol) = 1.022471e+04
#     stopping criterion: RTOL
# Solution found after 1951 iterations:
#     objective function f(sol) = 7.376636e+03
#     stopping criterion: RTOL
# Solution found after 527 iterations:
#     objective function f(sol) = 1.215060e+04
#     stopping criterion: RTOL
# Solution found after 527 iterations:
#     objective function f(sol) = 1.227147e+04
#     stopping criterion: RTOL
# Solution found after 1312 iterations:
#     objective function f(sol) = 6.271906e+03
#     stopping criterion: RTOL
# Solution found after 1666 iterations:
#     objective function f(sol) = 7.653521e+03
#     stopping criterion: RTOL
# Solution found after 527 iterations:
#     objective function f(sol) = 1.161729e+04
#     stopping criterion: RTOL
# Solution found after 1965 iterations:
#     objective function f(sol) = 6.930035e+03
#     stopping criterion: RTOL
# Solution found after 668 iterations:
#     objective function f(sol) = 1.140176e+04
#     stopping criterion: RTOL
# Solution found after 1310 iterations:
#     objective function f(sol) = 6.342467e+03
#     stopping criterion: RTOL
# Solution found after 2454 iterations:
#     objective function f(sol) = 5.611707e+03
#     stopping criterion: RTOL
# Solution found after 668 iterations:
#     objective function f(sol) = 1.127588e+04
#     stopping criterion: RTOL
# Solution found after 1455 iterations:
#     objective function f(sol) = 6.418783e+03
#     stopping criterion: RTOL
# Solution found after 1029 iterations:
#     objective function f(sol) = 5.901945e+03
#     stopping criterion: RTOL
# Solution found after 669 iterations:
#     objective function f(sol) = 1.138082e+04
#     stopping criterion: RTOL
# Solution found after 387 iterations:
#     objective function f(sol) = 1.309970e+04
#     stopping criterion: RTOL
# Solution found after 2437 iterations:
#     objective function f(sol) = 5.709235e+03
#     stopping criterion: RTOL
# 0 m done over 5
# 1 m done over 5
# 2 m done over 5
# 3 m done over 5
# 4 m done over 5
# 1 m done over 5
# Solution found after 824 iterations:
#     objective function f(sol) = 1.024173e+04
#     stopping criterion: RTOL
# Solution found after 974 iterations:
#     objective function f(sol) = 9.312674e+03
#     stopping criterion: RTOL
# Solution found after 1582 iterations:
#     objective function f(sol) = 7.494120e+03
#     stopping criterion: RTOL
# Solution found after 1201 iterations:
#     objective function f(sol) = 7.074944e+03
#     stopping criterion: RTOL
# Solution found after 1123 iterations:
#     objective function f(sol) = 9.151736e+03
#     stopping criterion: RTOL
# Solution found after 1278 iterations:
#     objective function f(sol) = 7.979618e+03
#     stopping criterion: RTOL
# Solution found after 1498 iterations:
#     objective function f(sol) = 7.273298e+03
#     stopping criterion: RTOL
# Solution found after 1674 iterations:
#     objective function f(sol) = 7.168319e+03
#     stopping criterion: RTOL
# Solution found after 387 iterations:
#     objective function f(sol) = 1.216534e+04
#     stopping criterion: RTOL
# Solution found after 1430 iterations:
#     objective function f(sol) = 8.060900e+03
#     stopping criterion: RTOL
# Solution found after 1778 iterations:
#     objective function f(sol) = 6.936118e+03
#     stopping criterion: RTOL
# Solution found after 106 iterations:
#     objective function f(sol) = 1.303532e+04
#     stopping criterion: RTOL
# Solution found after 106 iterations:
#     objective function f(sol) = 1.278623e+04
#     stopping criterion: RTOL
# Solution found after 1432 iterations:
#     objective function f(sol) = 7.861940e+03
#     stopping criterion: RTOL
# Solution found after 388 iterations:
#     objective function f(sol) = 1.196035e+04
#     stopping criterion: RTOL
# Solution found after 824 iterations:
#     objective function f(sol) = 9.873762e+03
#     stopping criterion: RTOL
# Solution found after 900 iterations:
#     objective function f(sol) = 6.815128e+03
#     stopping criterion: RTOL
# Solution found after 1817 iterations:
#     objective function f(sol) = 7.114477e+03
#     stopping criterion: RTOL
# Solution found after 388 iterations:
#     objective function f(sol) = 1.240937e+04
#     stopping criterion: RTOL
# Solution found after 1586 iterations:
#     objective function f(sol) = 7.549512e+03
#     stopping criterion: RTOL
# 0 m done over 5
# 1 m done over 5
# 2 m done over 5
# 3 m done over 5
# 4 m done over 5
# 2 m done over 5
# Solution found after 1148 iterations:
#     objective function f(sol) = 8.037514e+03
#     stopping criterion: RTOL
# Solution found after 462 iterations:
#     objective function f(sol) = 6.696717e+03
#     stopping criterion: RTOL
# Solution found after 610 iterations:
#     objective function f(sol) = 7.052610e+03
#     stopping criterion: RTOL
# Solution found after 1293 iterations:
#     objective function f(sol) = 8.023508e+03
#     stopping criterion: RTOL
# Solution found after 1139 iterations:
#     objective function f(sol) = 8.089735e+03
#     stopping criterion: RTOL
# Solution found after 611 iterations:
#     objective function f(sol) = 6.967413e+03
#     stopping criterion: RTOL
# Solution found after 1371 iterations:
#     objective function f(sol) = 7.534910e+03
#     stopping criterion: RTOL
# Solution found after 840 iterations:
#     objective function f(sol) = 9.203702e+03
#     stopping criterion: RTOL
# Solution found after 1146 iterations:
#     objective function f(sol) = 8.032862e+03
#     stopping criterion: RTOL
# Solution found after 842 iterations:
#     objective function f(sol) = 8.942866e+03
#     stopping criterion: RTOL
# Solution found after 107 iterations:
#     objective function f(sol) = 1.191624e+04
#     stopping criterion: RTOL
# Solution found after 1069 iterations:
#     objective function f(sol) = 7.519546e+03
#     stopping criterion: RTOL
# Solution found after 1143 iterations:
#     objective function f(sol) = 8.061072e+03
#     stopping criterion: RTOL
# Solution found after 1374 iterations:
#     objective function f(sol) = 7.482277e+03
#     stopping criterion: RTOL
# Solution found after 106 iterations:
#     objective function f(sol) = 1.206979e+04
#     stopping criterion: RTOL
# Solution found after 247 iterations:
#     objective function f(sol) = 1.129853e+04
#     stopping criterion: RTOL
# Solution found after 840 iterations:
#     objective function f(sol) = 9.144701e+03
#     stopping criterion: RTOL
# Solution found after 1142 iterations:
#     objective function f(sol) = 8.083696e+03
#     stopping criterion: RTOL
# Solution found after 989 iterations:
#     objective function f(sol) = 8.706039e+03
#     stopping criterion: RTOL
# Solution found after 1144 iterations:
#     objective function f(sol) = 8.079622e+03
#     stopping criterion: RTOL
# 0 m done over 5
# 1 m done over 5
# 2 m done over 5
# 3 m done over 5
# 4 m done over 5
# 3 m done over 5
# Solution found after 107 iterations:
#     objective function f(sol) = 1.001315e+04
#     stopping criterion: RTOL
# Solution found after 851 iterations:
#     objective function f(sol) = 8.556449e+03
#     stopping criterion: RTOL
# Solution found after 997 iterations:
#     objective function f(sol) = 7.888376e+03
#     stopping criterion: RTOL
# Solution found after 250 iterations:
#     objective function f(sol) = 9.695343e+03
#     stopping criterion: RTOL
# Solution found after 852 iterations:
#     objective function f(sol) = 8.587840e+03
#     stopping criterion: RTOL
# Solution found after 391 iterations:
#     objective function f(sol) = 9.681545e+03
#     stopping criterion: RTOL
# Solution found after 769 iterations:
#     objective function f(sol) = 7.553981e+03
#     stopping criterion: RTOL
# Solution found after 392 iterations:
#     objective function f(sol) = 9.922074e+03
#     stopping criterion: RTOL
# Solution found after 697 iterations:
#     objective function f(sol) = 8.773815e+03
#     stopping criterion: RTOL
# Solution found after 772 iterations:
#     objective function f(sol) = 7.886222e+03
#     stopping criterion: RTOL
# Solution found after 466 iterations:
#     objective function f(sol) = 7.375925e+03
#     stopping criterion: RTOL
# Solution found after 391 iterations:
#     objective function f(sol) = 9.551465e+03
#     stopping criterion: RTOL
# Solution found after 106 iterations:
#     objective function f(sol) = 1.022863e+04
#     stopping criterion: RTOL
# Solution found after 697 iterations:
#     objective function f(sol) = 8.833346e+03
#     stopping criterion: RTOL
# Solution found after 249 iterations:
#     objective function f(sol) = 9.742287e+03
#     stopping criterion: RTOL
# Solution found after 538 iterations:
#     objective function f(sol) = 9.438347e+03
#     stopping criterion: RTOL
# Solution found after 538 iterations:
#     objective function f(sol) = 9.404229e+03
#     stopping criterion: RTOL
# Solution found after 389 iterations:
#     objective function f(sol) = 1.005890e+04
#     stopping criterion: RTOL
# Solution found after 249 iterations:
#     objective function f(sol) = 9.894267e+03
#     stopping criterion: RTOL
# Solution found after 616 iterations:
#     objective function f(sol) = 7.267529e+03
#     stopping criterion: RTOL
# 0 m done over 5
# 1 m done over 5
# 2 m done over 5
# 3 m done over 5
# 4 m done over 5
# 4 m done over 5
# Solution found after 107 iterations:
#     objective function f(sol) = 8.554923e+03
#     stopping criterion: RTOL
# Solution found after 39 iterations:
#     objective function f(sol) = 7.636237e+03
#     stopping criterion: RTOL
# Solution found after 251 iterations:
#     objective function f(sol) = 8.343296e+03
#     stopping criterion: RTOL
# Solution found after 627 iterations:
#     objective function f(sol) = 7.480979e+03
#     stopping criterion: RTOL
# Solution found after 399 iterations:
#     objective function f(sol) = 8.294390e+03
#     stopping criterion: RTOL
# Solution found after 45 iterations:
#     objective function f(sol) = 7.620480e+03
#     stopping criterion: RTOL
# Solution found after 182 iterations:
#     objective function f(sol) = 7.417215e+03
#     stopping criterion: RTOL
# Solution found after 397 iterations:
#     objective function f(sol) = 8.493627e+03
#     stopping criterion: RTOL
# Solution found after 43 iterations:
#     objective function f(sol) = 7.598137e+03
#     stopping criterion: RTOL
# Solution found after 547 iterations:
#     objective function f(sol) = 8.008852e+03
#     stopping criterion: RTOL
# Solution found after 473 iterations:
#     objective function f(sol) = 7.446637e+03
#     stopping criterion: RTOL
# Solution found after 400 iterations:
#     objective function f(sol) = 8.264796e+03
#     stopping criterion: RTOL
# Solution found after 46 iterations:
#     objective function f(sol) = 7.603301e+03
#     stopping criterion: RTOL
# Solution found after 41 iterations:
#     objective function f(sol) = 7.657913e+03
#     stopping criterion: RTOL
# Solution found after 179 iterations:
#     objective function f(sol) = 7.380645e+03
#     stopping criterion: RTOL
# Solution found after 109 iterations:
#     objective function f(sol) = 8.385165e+03
#     stopping criterion: RTOL
# Solution found after 326 iterations:
#     objective function f(sol) = 7.556103e+03
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 7.605401e+03
#     stopping criterion: RTOL
# Solution found after 393 iterations:
#     objective function f(sol) = 8.368346e+03
#     stopping criterion: RTOL
# Solution found after 395 iterations:
#     objective function f(sol) = 8.276741e+03
#     stopping criterion: RTOL
# 0 m done over 5
# 1 m done over 5
# 2 m done over 5
# 3 m done over 5
# 4 m done over 5
# part 1 done
# 0 m done over 5
# Solution found after 4014 iterations:
#     objective function f(sol) = 1.433721e+02
#     stopping criterion: RTOL
# Solution found after 3986 iterations:
#     objective function f(sol) = 1.447775e+02
#     stopping criterion: RTOL
# Solution found after 3958 iterations:
#     objective function f(sol) = 1.451614e+02
#     stopping criterion: RTOL
# Solution found after 3941 iterations:
#     objective function f(sol) = 1.460174e+02
#     stopping criterion: RTOL
# Solution found after 3989 iterations:
#     objective function f(sol) = 1.462369e+02
#     stopping criterion: RTOL
# Solution found after 4049 iterations:
#     objective function f(sol) = 1.439569e+02
#     stopping criterion: RTOL
# Solution found after 4022 iterations:
#     objective function f(sol) = 1.457618e+02
#     stopping criterion: RTOL
# Solution found after 3950 iterations:
#     objective function f(sol) = 1.461077e+02
#     stopping criterion: RTOL
# Solution found after 4004 iterations:
#     objective function f(sol) = 1.444419e+02
#     stopping criterion: RTOL
# Solution found after 3970 iterations:
#     objective function f(sol) = 1.428027e+02
#     stopping criterion: RTOL
# Solution found after 4014 iterations:
#     objective function f(sol) = 1.452846e+02
#     stopping criterion: RTOL
# Solution found after 3958 iterations:
#     objective function f(sol) = 1.441739e+02
#     stopping criterion: RTOL
# Solution found after 4039 iterations:
#     objective function f(sol) = 1.432668e+02
#     stopping criterion: RTOL
# Solution found after 4038 iterations:
#     objective function f(sol) = 1.471158e+02
#     stopping criterion: RTOL
# Solution found after 4026 iterations:
#     objective function f(sol) = 1.446465e+02
#     stopping criterion: RTOL
# Solution found after 3986 iterations:
#     objective function f(sol) = 1.448727e+02
#     stopping criterion: RTOL
# Solution found after 4042 iterations:
#     objective function f(sol) = 1.436721e+02
#     stopping criterion: RTOL
# Solution found after 4148 iterations:
#     objective function f(sol) = 1.460439e+02
#     stopping criterion: RTOL
# Solution found after 4009 iterations:
#     objective function f(sol) = 1.432575e+02
#     stopping criterion: RTOL
# Solution found after 4104 iterations:
#     objective function f(sol) = 1.420007e+02
#     stopping criterion: RTOL
# 0 m done over 5
# 1 m done over 5
# 2 m done over 5
# 3 m done over 5
# 4 m done over 5
# 1 m done over 5
# Solution found after 3377 iterations:
#     objective function f(sol) = 3.894888e+02
#     stopping criterion: RTOL
# Solution found after 3417 iterations:
#     objective function f(sol) = 3.882890e+02
#     stopping criterion: RTOL
# Solution found after 3340 iterations:
#     objective function f(sol) = 3.872244e+02
#     stopping criterion: RTOL
# Solution found after 3436 iterations:
#     objective function f(sol) = 3.936148e+02
#     stopping criterion: RTOL
# Solution found after 3365 iterations:
#     objective function f(sol) = 3.873224e+02
#     stopping criterion: RTOL
# Solution found after 3383 iterations:
#     objective function f(sol) = 3.820172e+02
#     stopping criterion: RTOL
# Solution found after 3370 iterations:
#     objective function f(sol) = 3.802903e+02
#     stopping criterion: RTOL
# Solution found after 3419 iterations:
#     objective function f(sol) = 3.814292e+02
#     stopping criterion: RTOL
# Solution found after 3341 iterations:
#     objective function f(sol) = 3.804203e+02
#     stopping criterion: RTOL
# Solution found after 3462 iterations:
#     objective function f(sol) = 3.822683e+02
#     stopping criterion: RTOL
# Solution found after 3384 iterations:
#     objective function f(sol) = 3.917874e+02
#     stopping criterion: RTOL
# Solution found after 3403 iterations:
#     objective function f(sol) = 3.868499e+02
#     stopping criterion: RTOL
# Solution found after 3413 iterations:
#     objective function f(sol) = 3.845668e+02
#     stopping criterion: RTOL
# Solution found after 3462 iterations:
#     objective function f(sol) = 3.844606e+02
#     stopping criterion: RTOL
# Solution found after 3387 iterations:
#     objective function f(sol) = 3.917037e+02
#     stopping criterion: RTOL
# Solution found after 3408 iterations:
#     objective function f(sol) = 3.810371e+02
#     stopping criterion: RTOL
# Solution found after 3390 iterations:
#     objective function f(sol) = 3.881458e+02
#     stopping criterion: RTOL
# Solution found after 3334 iterations:
#     objective function f(sol) = 3.869267e+02
#     stopping criterion: RTOL
# Solution found after 3385 iterations:
#     objective function f(sol) = 3.865116e+02
#     stopping criterion: RTOL
# Solution found after 3362 iterations:
#     objective function f(sol) = 3.855288e+02
#     stopping criterion: RTOL
# 0 m done over 5
# 1 m done over 5
# 2 m done over 5
# 3 m done over 5
# 4 m done over 5
# 2 m done over 5
# Solution found after 2990 iterations:
#     objective function f(sol) = 5.890676e+02
#     stopping criterion: RTOL
# Solution found after 2928 iterations:
#     objective function f(sol) = 5.998627e+02
#     stopping criterion: RTOL
# Solution found after 2891 iterations:
#     objective function f(sol) = 5.841361e+02
#     stopping criterion: RTOL
# Solution found after 2991 iterations:
#     objective function f(sol) = 5.830470e+02
#     stopping criterion: RTOL
# Solution found after 2991 iterations:
#     objective function f(sol) = 5.901741e+02
#     stopping criterion: RTOL
# Solution found after 2978 iterations:
#     objective function f(sol) = 5.976950e+02
#     stopping criterion: RTOL
# Solution found after 2926 iterations:
#     objective function f(sol) = 5.880325e+02
#     stopping criterion: RTOL
# Solution found after 2932 iterations:
#     objective function f(sol) = 6.006104e+02
#     stopping criterion: RTOL
# Solution found after 2908 iterations:
#     objective function f(sol) = 5.934123e+02
#     stopping criterion: RTOL
# Solution found after 2887 iterations:
#     objective function f(sol) = 5.856631e+02
#     stopping criterion: RTOL
# Solution found after 2987 iterations:
#     objective function f(sol) = 5.839337e+02
#     stopping criterion: RTOL
# Solution found after 3031 iterations:
#     objective function f(sol) = 5.772717e+02
#     stopping criterion: RTOL
# Solution found after 2977 iterations:
#     objective function f(sol) = 6.038981e+02
#     stopping criterion: RTOL
# Solution found after 3022 iterations:
#     objective function f(sol) = 5.848007e+02
#     stopping criterion: RTOL
# Solution found after 2960 iterations:
#     objective function f(sol) = 5.916088e+02
#     stopping criterion: RTOL
# Solution found after 3015 iterations:
#     objective function f(sol) = 5.945102e+02
#     stopping criterion: RTOL
# Solution found after 2943 iterations:
#     objective function f(sol) = 5.854488e+02
#     stopping criterion: RTOL
# Solution found after 2974 iterations:
#     objective function f(sol) = 5.868039e+02
#     stopping criterion: RTOL
# Solution found after 2944 iterations:
#     objective function f(sol) = 5.925578e+02
#     stopping criterion: RTOL
# Solution found after 2961 iterations:
#     objective function f(sol) = 6.044901e+02
#     stopping criterion: RTOL
# 0 m done over 5
# 1 m done over 5
# 2 m done over 5
# 3 m done over 5
# 4 m done over 5
# 3 m done over 5
# Solution found after 2548 iterations:
#     objective function f(sol) = 7.631163e+02
#     stopping criterion: RTOL
# Solution found after 2498 iterations:
#     objective function f(sol) = 7.699701e+02
#     stopping criterion: RTOL
# Solution found after 2503 iterations:
#     objective function f(sol) = 7.645647e+02
#     stopping criterion: RTOL
# Solution found after 2620 iterations:
#     objective function f(sol) = 7.650225e+02
#     stopping criterion: RTOL
# Solution found after 2562 iterations:
#     objective function f(sol) = 7.563035e+02
#     stopping criterion: RTOL
# Solution found after 2535 iterations:
#     objective function f(sol) = 7.701969e+02
#     stopping criterion: RTOL
# Solution found after 2546 iterations:
#     objective function f(sol) = 7.768998e+02
#     stopping criterion: RTOL
# Solution found after 2538 iterations:
#     objective function f(sol) = 7.708918e+02
#     stopping criterion: RTOL
# Solution found after 2567 iterations:
#     objective function f(sol) = 7.773491e+02
#     stopping criterion: RTOL
# Solution found after 2519 iterations:
#     objective function f(sol) = 7.737388e+02
#     stopping criterion: RTOL
# Solution found after 2571 iterations:
#     objective function f(sol) = 7.699216e+02
#     stopping criterion: RTOL
# Solution found after 2510 iterations:
#     objective function f(sol) = 7.724036e+02
#     stopping criterion: RTOL
# Solution found after 2534 iterations:
#     objective function f(sol) = 7.676984e+02
#     stopping criterion: RTOL
# Solution found after 2555 iterations:
#     objective function f(sol) = 7.635132e+02
#     stopping criterion: RTOL
# Solution found after 2541 iterations:
#     objective function f(sol) = 7.622326e+02
#     stopping criterion: RTOL
# Solution found after 2616 iterations:
#     objective function f(sol) = 7.689305e+02
#     stopping criterion: RTOL
# Solution found after 2637 iterations:
#     objective function f(sol) = 7.723146e+02
#     stopping criterion: RTOL
# Solution found after 2580 iterations:
#     objective function f(sol) = 7.790423e+02
#     stopping criterion: RTOL
# Solution found after 2606 iterations:
#     objective function f(sol) = 7.801638e+02
#     stopping criterion: RTOL
# Solution found after 2535 iterations:
#     objective function f(sol) = 7.761653e+02
#     stopping criterion: RTOL
# 0 m done over 5
# 1 m done over 5
# 2 m done over 5
# 3 m done over 5
# 4 m done over 5
# 4 m done over 5
# Solution found after 1917 iterations:
#     objective function f(sol) = 9.338809e+02
#     stopping criterion: RTOL
# Solution found after 1843 iterations:
#     objective function f(sol) = 9.356597e+02
#     stopping criterion: RTOL
# Solution found after 1964 iterations:
#     objective function f(sol) = 9.354804e+02
#     stopping criterion: RTOL
# Solution found after 1751 iterations:
#     objective function f(sol) = 9.363282e+02
#     stopping criterion: RTOL
# Solution found after 1749 iterations:
#     objective function f(sol) = 9.360963e+02
#     stopping criterion: RTOL
# Solution found after 1877 iterations:
#     objective function f(sol) = 9.424202e+02
#     stopping criterion: RTOL
# Solution found after 1922 iterations:
#     objective function f(sol) = 9.343040e+02
#     stopping criterion: RTOL
# Solution found after 1817 iterations:
#     objective function f(sol) = 9.385219e+02
#     stopping criterion: RTOL
# Solution found after 1848 iterations:
#     objective function f(sol) = 9.354624e+02
#     stopping criterion: RTOL
# Solution found after 1894 iterations:
#     objective function f(sol) = 9.404366e+02
#     stopping criterion: RTOL
# Solution found after 1988 iterations:
#     objective function f(sol) = 9.410337e+02
#     stopping criterion: RTOL
# Solution found after 1838 iterations:
#     objective function f(sol) = 9.305331e+02
#     stopping criterion: RTOL
# Solution found after 1939 iterations:
#     objective function f(sol) = 9.330172e+02
#     stopping criterion: RTOL
# Solution found after 1842 iterations:
#     objective function f(sol) = 9.369546e+02
#     stopping criterion: RTOL
# Solution found after 1947 iterations:
#     objective function f(sol) = 9.413961e+02
#     stopping criterion: RTOL
# Solution found after 1809 iterations:
#     objective function f(sol) = 9.345191e+02
#     stopping criterion: RTOL
# Solution found after 1694 iterations:
#     objective function f(sol) = 9.361795e+02
#     stopping criterion: RTOL
# Solution found after 1875 iterations:
#     objective function f(sol) = 9.375827e+02
#     stopping criterion: RTOL
# Solution found after 1828 iterations:
#     objective function f(sol) = 9.406997e+02
#     stopping criterion: RTOL
# Solution found after 1825 iterations:
#     objective function f(sol) = 9.309676e+02
#     stopping criterion: RTOL
# 0 m done over 5
# 1 m done over 5
# 2 m done over 5
# 3 m done over 5
# 4 m done over 5

# %% [markdown]
# Plot both phase transition matrices as images with a colorbar. Make sure to properly name the axes and title the images.

# %%
plt.figure(figsize=(10,5))
plt.subplot(121)
plt.imshow(pt_matrix_1norm)
plt.xlabel('mn_ratios')
plt.ylabel('thresh')
plt.colorbar()

plt.subplot(122)
plt.imshow(pt_matrix_2norm)
plt.xlabel('mn_ratios')
plt.ylabel('thresh')
plt.colorbar()

# %% [markdown]
# ### Question 18
#
# Do the phase transition plots above provide any justification for choosing one $p-$norm interpolation over the other? Why?

# %% [markdown]
# **Your answer here.**
